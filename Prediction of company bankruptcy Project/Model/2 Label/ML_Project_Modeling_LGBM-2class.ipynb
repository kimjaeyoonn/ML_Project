# %% [markdown]
# # Library import

# %%
# 필요한 라이브러리 설치
import warnings
warnings.filterwarnings('ignore')

import os
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import sklearn

# %% [markdown]
# # read_csv (10 Label)

# %%
# 파일 받아오기
# 2class

Mdf = pd.read_csv('Mdf_10label.csv')
Kdf = pd.read_csv('Kdf_10label.csv')
Sdf = pd.read_csv('Sdf_10label.csv')

# %% [markdown]
# # Change class to 2 Label

# %%
Mdf = Mdf.replace({'bankruptcy':-5},{'bankruptcy':0})
#Mdf = Mdf.replace({'bankruptcy':1},{'bankruptcy':1})
Mdf = Mdf.replace({'bankruptcy':2},{'bankruptcy':1})
Mdf = Mdf.replace({'bankruptcy':3},{'bankruptcy':1})
Mdf = Mdf.replace({'bankruptcy':4},{'bankruptcy':1})
Mdf = Mdf.replace({'bankruptcy':5},{'bankruptcy':1})
idx=Mdf[Mdf['bankruptcy']==-1].index
Mdf.drop(idx,inplace=True)
idx=Mdf[Mdf['bankruptcy']==-2].index
Mdf.drop(idx,inplace=True)
idx=Mdf[Mdf['bankruptcy']==-3].index
Mdf.drop(idx,inplace=True)
idx=Mdf[Mdf['bankruptcy']==-4].index
Mdf.drop(idx,inplace=True)

# %%
Kdf = Kdf.replace({'bankruptcy':-5},{'bankruptcy':0})
#Kdf = Kdf.replace({'bankruptcy':1},{'bankruptcy':1})
Kdf = Kdf.replace({'bankruptcy':2},{'bankruptcy':1})
Kdf = Kdf.replace({'bankruptcy':3},{'bankruptcy':1})
Kdf = Kdf.replace({'bankruptcy':4},{'bankruptcy':1})
Kdf = Kdf.replace({'bankruptcy':5},{'bankruptcy':1})
idx=Kdf[Kdf['bankruptcy']==-1].index
Kdf.drop(idx,inplace=True)
idx=Kdf[Kdf['bankruptcy']==-2].index
Kdf.drop(idx,inplace=True)
idx=Kdf[Kdf['bankruptcy']==-3].index
Kdf.drop(idx,inplace=True)
idx=Kdf[Kdf['bankruptcy']==-4].index
Kdf.drop(idx,inplace=True)

# %%
Sdf = Sdf.replace({'bankruptcy':-5},{'bankruptcy':0})
#Sdf = Sdf.replace({'bankruptcy':1},{'bankruptcy':1})
Sdf = Sdf.replace({'bankruptcy':2},{'bankruptcy':1})
Sdf = Sdf.replace({'bankruptcy':3},{'bankruptcy':1})
Sdf = Sdf.replace({'bankruptcy':4},{'bankruptcy':1})
Sdf = Sdf.replace({'bankruptcy':5},{'bankruptcy':1})
idx=Sdf[Sdf['bankruptcy']==-1].index
Sdf.drop(idx,inplace=True)
idx=Sdf[Sdf['bankruptcy']==-2].index
Sdf.drop(idx,inplace=True)
idx=Sdf[Sdf['bankruptcy']==-3].index
Sdf.drop(idx,inplace=True)
idx=Sdf[Sdf['bankruptcy']==-4].index
Sdf.drop(idx,inplace=True)

# %% [markdown]
# # X, y 나누기

# %%
Mx = Mdf.drop(labels=['bankruptcy'], axis=1)
My = Mdf['bankruptcy'].to_frame()
Mx.head()
# Out:
#       attr1    attr2    attr3   attr4    attr5    attr6     attr7    attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     attr9   attr10  ...    attr55    attr56   attr57   attr58    attr59  \
# 0  1.1389  0.50494  ...  348690.0  0.121960  0.39718  0.87804  0.001924
# 1  1.6996  0.49788  ...    2304.6  0.121300  0.42002  0.85300  0.000000
# 2  1.3090  0.30408  ...    6332.7  0.241140  0.81774  0.76599  0.694840
# 3  1.0571  0.57353  ...   20545.0  0.054015  0.14207  0.94598  0.000000
# 4  1.1559  0.38677  ...    3186.6  0.134850  0.48431  0.86515  0.124440
#
#    attr60  attr61   attr62  attr63   attr64
# 0  8.4160  5.1372   82.658  4.4158   7.4277
# 1  4.1486  3.2732  107.350  3.4000  60.9870
# 2  4.9909  3.9510  134.270  2.7185   5.2078
# 3  4.5746  3.6147   86.435  4.2228   5.5497
# 4  6.3985  4.3158  127.210  2.8692   7.8980
#
# [5 rows x 64 columns]

# %%
Kx = Kdf.drop(labels=['bankruptcy'], axis=1)
Ky = Kdf['bankruptcy'].to_frame()
Kx.head()
# Out:
#       attr1    attr2    attr3   attr4    attr5    attr6     attr7    attr8  \
# 0  0.200550  0.37951  0.39641  2.0472  32.3510  0.38825  0.249760  1.33050
# 1  0.209120  0.49988  0.47225  1.9447  14.7860  0.00000  0.258340  0.99601
# 2  0.248660  0.69592  0.26713  1.5548  -1.1523  0.00000  0.309060  0.43695
# 3  0.081483  0.30734  0.45879  2.4928  51.9520  0.14988  0.092704  1.86610
# 4  0.187320  0.61323  0.22960  1.4063  -7.3128  0.18732  0.187320  0.63070
#
#     attr9   attr10  ...    attr55    attr56   attr57   attr58    attr59  \
# 0  1.1389  0.50494  ...  348690.0  0.121960  0.39718  0.87804  0.001924
# 1  1.6996  0.49788  ...    2304.6  0.121300  0.42002  0.85300  0.000000
# 2  1.3090  0.30408  ...    6332.7  0.241140  0.81774  0.76599  0.694840
# 3  1.0571  0.57353  ...   20545.0  0.054015  0.14207  0.94598  0.000000
# 4  1.1559  0.38677  ...    3186.6  0.134850  0.48431  0.86515  0.124440
#
#    attr60  attr61   attr62  attr63   attr64
# 0  8.4160  5.1372   82.658  4.4158   7.4277
# 1  4.1486  3.2732  107.350  3.4000  60.9870
# 2  4.9909  3.9510  134.270  2.7185   5.2078
# 3  4.5746  3.6147   86.435  4.2228   5.5497
# 4  6.3985  4.3158  127.210  2.8692   7.8980
#
# [5 rows x 64 columns]

# %%
Sx = Sdf.drop(labels=['bankruptcy'], axis=1)
Sy = Sdf['bankruptcy'].to_frame()
Sx.head()
# Out:
#       attr1    attr2     attr3   attr4    attr5     attr6     attr7    attr8  \
# 0  0.200550  0.37951  0.396410  2.0472  32.3510  0.388250  0.249760  1.33050
# 1  0.081483  0.30734  0.458790  2.4928  51.9520  0.149880  0.092704  1.86610
# 2  0.187320  0.61323  0.229600  1.4063  -7.3128  0.187320  0.187320  0.63070
# 3  0.009020  0.63202  0.053735  1.1263 -37.8420  0.000000  0.014434  0.58223
# 4 -0.027117  0.11148  0.119890  2.0754 -31.6430 -0.084883 -0.024300  7.67410
#
#      attr9   attr10  ...  attr54       attr55    attr56    attr57   attr58  \
# 0  1.13890  0.50494  ...  2.2480  348690.0000  0.121960  0.397180  0.87804
# 1  1.05710  0.57353  ...  2.4524   20545.0000  0.054015  0.142070  0.94598
# 2  1.15590  0.38677  ...  2.1184    3186.6000  0.134850  0.484310  0.86515
# 3  1.33320  0.36798  ...  0.9476       1.1263  0.180110  0.024512  0.84165
# 4  0.90732  0.85551  ...  1.1130    1366.5000 -0.102140 -0.031697  1.10210
#
#      attr59   attr61   attr62  attr63   attr64
# 0  0.001924   5.1372   82.658  4.4158  7.42770
# 1  0.000000   3.6147   86.435  4.2228  5.54970
# 2  0.124440   4.3158  127.210  2.8692  7.89800
# 3  0.340940   4.2382  116.500  3.1330  2.56030
# 4  0.000000  13.4610   76.732  4.7568  0.68991
#
# [5 rows x 59 columns]

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split # 학습, 테스트set 구분
Mx_train, Mx_test, My_train, My_test = train_test_split(Mx, My,test_size=0.3,random_state=2022)

# %%
from sklearn.model_selection import train_test_split # 학습, 테스트set 구분
Kx_train, Kx_test, Ky_train, Ky_test = train_test_split(Kx, Ky,test_size=0.3,random_state=2022)

# %%
from sklearn.model_selection import train_test_split # 학습, 테스트set 구분
Sx_train, Sx_test, Sy_train, Sy_test = train_test_split(Sx, Sy,test_size=0.3,random_state=2022)

# %% [markdown]
# # Oversampling 진행

# %%
# SMOTE 패키지로 oversampling 진행
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42, k_neighbors=5)
Mdf, My = smote.fit_resample(Mx_train, My_train)

sns.countplot(x=My['bankruptcy'])
plt.title('Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')
# Out:
# Text(0.5, 1.0, 'Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')

# %%
# SMOTE 패키지로 oversampling 진행
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42, k_neighbors=5)
Kdf, Ky = smote.fit_resample(Kx_train, Ky_train)

sns.countplot(x=Ky['bankruptcy'])
plt.title('Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')
# Out:
# Text(0.5, 1.0, 'Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')

# %%
# SMOTE 패키지로 oversampling 진행
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state=42, k_neighbors=5)
Sdf, Sy = smote.fit_resample(Sx_train, Sy_train)

sns.countplot(x=Sy['bankruptcy'])
plt.title('Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')
# Out:
# Text(0.5, 1.0, 'Class Distributions \n (0: Fin. Stable || 1: Fin. Unstable)')

# %% [markdown]
# # Modeling - LightGBM

# %%
from lightgbm import LGBMClassifier

# %%
Mlgbm = LGBMClassifier(n_estimators=100, max_depth=3)


evals = [(Mx_test,My_test)]
Mlgbm.fit(Mdf,My,early_stopping_rounds=100, eval_metric='logloss',
                eval_set=evals,verbose=True)
# Out:
# [1]	valid_0's binary_logloss: 0.648505
# [2]	valid_0's binary_logloss: 0.614085
# [3]	valid_0's binary_logloss: 0.581874
# [4]	valid_0's binary_logloss: 0.552323
# [5]	valid_0's binary_logloss: 0.530969
# [6]	valid_0's binary_logloss: 0.509012
# [7]	valid_0's binary_logloss: 0.490612
# [8]	valid_0's binary_logloss: 0.475464
# [9]	valid_0's binary_logloss: 0.463858
# [10]	valid_0's binary_logloss: 0.44937
# [11]	valid_0's binary_logloss: 0.438044
# [12]	valid_0's binary_logloss: 0.42718
# [13]	valid_0's binary_logloss: 0.418359
# [14]	valid_0's binary_logloss: 0.409496
# [15]	valid_0's binary_logloss: 0.40272
# [16]	valid_0's binary_logloss: 0.394602
# [17]	valid_0's binary_logloss: 0.387032
# [18]	valid_0's binary_logloss: 0.379601
# [19]	valid_0's binary_logloss: 0.373563
# [20]	valid_0's binary_logloss: 0.368771
# [21]	valid_0's binary_logloss: 0.362735
# [22]	valid_0's binary_logloss: 0.358602
# [23]	valid_0's binary_logloss: 0.354827
# [24]	valid_0's binary_logloss: 0.350795
# [25]	valid_0's binary_logloss: 0.345317
# [26]	valid_0's binary_logloss: 0.341478
# [27]	valid_0's binary_logloss: 0.337105
# [28]	valid_0's binary_logloss: 0.334919
# [29]	valid_0's binary_logloss: 0.332422
# [30]	valid_0's binary_logloss: 0.33046
# [31]	valid_0's binary_logloss: 0.326736
# [32]	valid_0's binary_logloss: 0.323694
# [33]	valid_0's binary_logloss: 0.321259
# [34]	valid_0's binary_logloss: 0.317497
# [35]	valid_0's binary_logloss: 0.316129
# [36]	valid_0's binary_logloss: 0.313697
# [37]	valid_0's binary_logloss: 0.311964
# [38]	valid_0's binary_logloss: 0.310588
# [39]	valid_0's binary_logloss: 0.307593
# [40]	valid_0's binary_logloss: 0.306316
# [41]	valid_0's binary_logloss: 0.30441
# [42]	valid_0's binary_logloss: 0.302752
# [43]	valid_0's binary_logloss: 0.301265
# [44]	valid_0's binary_logloss: 0.298686
# [45]	valid_0's binary_logloss: 0.297649
# [46]	valid_0's binary_logloss: 0.296265
# [47]	valid_0's binary_logloss: 0.295245
# [48]	valid_0's binary_logloss: 0.291817
# [49]	valid_0's binary_logloss: 0.291061
# [50]	valid_0's binary_logloss: 0.289555
# [51]	valid_0's binary_logloss: 0.286315
# [52]	valid_0's binary_logloss: 0.284719
# [53]	valid_0's binary_logloss: 0.282573
# [54]	valid_0's binary_logloss: 0.281026
# [55]	valid_0's binary_logloss: 0.280392
# [56]	valid_0's binary_logloss: 0.278702
# [57]	valid_0's binary_logloss: 0.277417
# [58]	valid_0's binary_logloss: 0.274588
# [59]	valid_0's binary_logloss: 0.273096
# [60]	valid_0's binary_logloss: 0.271663
# [61]	valid_0's binary_logloss: 0.269071
# [62]	valid_0's binary_logloss: 0.268462
# [63]	valid_0's binary_logloss: 0.267529
# [64]	valid_0's binary_logloss: 0.266992
# [65]	valid_0's binary_logloss: 0.265421
# [66]	valid_0's binary_logloss: 0.264784
# [67]	valid_0's binary_logloss: 0.263003
# [68]	valid_0's binary_logloss: 0.261052
# [69]	valid_0's binary_logloss: 0.260014
# [70]	valid_0's binary_logloss: 0.25931
# [71]	valid_0's binary_logloss: 0.258831
# [72]	valid_0's binary_logloss: 0.256791
# [73]	valid_0's binary_logloss: 0.256099
# [74]	valid_0's binary_logloss: 0.254463
# [75]	valid_0's binary_logloss: 0.253236
# [76]	valid_0's binary_logloss: 0.252397
# [77]	valid_0's binary_logloss: 0.251525
# [78]	valid_0's binary_logloss: 0.250712
# [79]	valid_0's binary_logloss: 0.249467
# [80]	valid_0's binary_logloss: 0.247756
# [81]	valid_0's binary_logloss: 0.246952
# [82]	valid_0's binary_logloss: 0.244291
# [83]	valid_0's binary_logloss: 0.243523
# [84]	valid_0's binary_logloss: 0.243434
# [85]	valid_0's binary_logloss: 0.242902
# [86]	valid_0's binary_logloss: 0.241024
# [87]	valid_0's binary_logloss: 0.240472
# [88]	valid_0's binary_logloss: 0.239127
# [89]	valid_0's binary_logloss: 0.237874
# [90]	valid_0's binary_logloss: 0.237074
# [91]	valid_0's binary_logloss: 0.235767
# [92]	valid_0's binary_logloss: 0.234894
# [93]	valid_0's binary_logloss: 0.233949
# [94]	valid_0's binary_logloss: 0.233444
# [95]	valid_0's binary_logloss: 0.232932
# [96]	valid_0's binary_logloss: 0.231438
# [97]	valid_0's binary_logloss: 0.230342
# [98]	valid_0's binary_logloss: 0.230391
# [99]	valid_0's binary_logloss: 0.228446
# [100]	valid_0's binary_logloss: 0.228118
# LGBMClassifier(max_depth=3)

# %%
Klgbm = LGBMClassifier(n_estimators=100, max_depth=3)


evals = [(Kx_test,Ky_test)]
Klgbm.fit(Kdf,Ky,early_stopping_rounds=100, eval_metric='logloss',
                eval_set=evals,verbose=True)
# Out:
# [1]	valid_0's binary_logloss: 0.665913
# [2]	valid_0's binary_logloss: 0.641944
# [3]	valid_0's binary_logloss: 0.619671
# [4]	valid_0's binary_logloss: 0.601912
# [5]	valid_0's binary_logloss: 0.586557
# [6]	valid_0's binary_logloss: 0.573606
# [7]	valid_0's binary_logloss: 0.56077
# [8]	valid_0's binary_logloss: 0.550853
# [9]	valid_0's binary_logloss: 0.541084
# [10]	valid_0's binary_logloss: 0.534004
# [11]	valid_0's binary_logloss: 0.525311
# [12]	valid_0's binary_logloss: 0.519793
# [13]	valid_0's binary_logloss: 0.51336
# [14]	valid_0's binary_logloss: 0.506893
# [15]	valid_0's binary_logloss: 0.500183
# [16]	valid_0's binary_logloss: 0.49396
# [17]	valid_0's binary_logloss: 0.489105
# [18]	valid_0's binary_logloss: 0.484703
# [19]	valid_0's binary_logloss: 0.480333
# [20]	valid_0's binary_logloss: 0.477314
# [21]	valid_0's binary_logloss: 0.473164
# [22]	valid_0's binary_logloss: 0.469833
# [23]	valid_0's binary_logloss: 0.467171
# [24]	valid_0's binary_logloss: 0.463789
# [25]	valid_0's binary_logloss: 0.459943
# [26]	valid_0's binary_logloss: 0.457539
# [27]	valid_0's binary_logloss: 0.453161
# [28]	valid_0's binary_logloss: 0.451244
# [29]	valid_0's binary_logloss: 0.448985
# [30]	valid_0's binary_logloss: 0.446127
# [31]	valid_0's binary_logloss: 0.44407
# [32]	valid_0's binary_logloss: 0.44177
# [33]	valid_0's binary_logloss: 0.439677
# [34]	valid_0's binary_logloss: 0.437426
# [35]	valid_0's binary_logloss: 0.434965
# [36]	valid_0's binary_logloss: 0.432857
# [37]	valid_0's binary_logloss: 0.430783
# [38]	valid_0's binary_logloss: 0.429439
# [39]	valid_0's binary_logloss: 0.427833
# [40]	valid_0's binary_logloss: 0.425638
# [41]	valid_0's binary_logloss: 0.422696
# [42]	valid_0's binary_logloss: 0.420077
# [43]	valid_0's binary_logloss: 0.419018
# [44]	valid_0's binary_logloss: 0.417514
# [45]	valid_0's binary_logloss: 0.415692
# [46]	valid_0's binary_logloss: 0.414467
# [47]	valid_0's binary_logloss: 0.412786
# [48]	valid_0's binary_logloss: 0.411886
# [49]	valid_0's binary_logloss: 0.410643
# [50]	valid_0's binary_logloss: 0.408924
# [51]	valid_0's binary_logloss: 0.407501
# [52]	valid_0's binary_logloss: 0.406439
# [53]	valid_0's binary_logloss: 0.405366
# [54]	valid_0's binary_logloss: 0.403886
# [55]	valid_0's binary_logloss: 0.401995
# [56]	valid_0's binary_logloss: 0.401388
# [57]	valid_0's binary_logloss: 0.400201
# [58]	valid_0's binary_logloss: 0.399459
# [59]	valid_0's binary_logloss: 0.397798
# [60]	valid_0's binary_logloss: 0.394944
# [61]	valid_0's binary_logloss: 0.393424
# [62]	valid_0's binary_logloss: 0.392579
# [63]	valid_0's binary_logloss: 0.39143
# [64]	valid_0's binary_logloss: 0.389507
# [65]	valid_0's binary_logloss: 0.38698
# [66]	valid_0's binary_logloss: 0.385874
# [67]	valid_0's binary_logloss: 0.384857
# [68]	valid_0's binary_logloss: 0.383806
# [69]	valid_0's binary_logloss: 0.382158
# [70]	valid_0's binary_logloss: 0.381555
# [71]	valid_0's binary_logloss: 0.380719
# [72]	valid_0's binary_logloss: 0.378801
# [73]	valid_0's binary_logloss: 0.378029
# [74]	valid_0's binary_logloss: 0.377257
# [75]	valid_0's binary_logloss: 0.376205
# [76]	valid_0's binary_logloss: 0.375353
# [77]	valid_0's binary_logloss: 0.374794
# [78]	valid_0's binary_logloss: 0.373715
# [79]	valid_0's binary_logloss: 0.372616
# [80]	valid_0's binary_logloss: 0.371506
# [81]	valid_0's binary_logloss: 0.370266
# [82]	valid_0's binary_logloss: 0.369107
# [83]	valid_0's binary_logloss: 0.368114
# [84]	valid_0's binary_logloss: 0.36705
# [85]	valid_0's binary_logloss: 0.365112
# [86]	valid_0's binary_logloss: 0.364377
# [87]	valid_0's binary_logloss: 0.36392
# [88]	valid_0's binary_logloss: 0.363244
# [89]	valid_0's binary_logloss: 0.362853
# [90]	valid_0's binary_logloss: 0.362261
# [91]	valid_0's binary_logloss: 0.36125
# [92]	valid_0's binary_logloss: 0.360255
# [93]	valid_0's binary_logloss: 0.359072
# [94]	valid_0's binary_logloss: 0.358594
# [95]	valid_0's binary_logloss: 0.357222
# [96]	valid_0's binary_logloss: 0.356913
# [97]	valid_0's binary_logloss: 0.356119
# [98]	valid_0's binary_logloss: 0.355055
# [99]	valid_0's binary_logloss: 0.353983
# [100]	valid_0's binary_logloss: 0.353573
# LGBMClassifier(max_depth=3)

# %%
Slgbm = LGBMClassifier(n_estimators=100, max_depth=3)


evals = [(Sx_test,Sy_test)]
Slgbm.fit(Sdf,Sy,early_stopping_rounds=100, eval_metric='logloss',
                eval_set=evals,verbose=True)
# Out:
# [1]	valid_0's binary_logloss: 0.667262
# [2]	valid_0's binary_logloss: 0.645945
# [3]	valid_0's binary_logloss: 0.628258
# [4]	valid_0's binary_logloss: 0.61191
# [5]	valid_0's binary_logloss: 0.598743
# [6]	valid_0's binary_logloss: 0.587293
# [7]	valid_0's binary_logloss: 0.575596
# [8]	valid_0's binary_logloss: 0.565803
# [9]	valid_0's binary_logloss: 0.55851
# [10]	valid_0's binary_logloss: 0.550189
# [11]	valid_0's binary_logloss: 0.543702
# [12]	valid_0's binary_logloss: 0.537924
# [13]	valid_0's binary_logloss: 0.532372
# [14]	valid_0's binary_logloss: 0.526917
# [15]	valid_0's binary_logloss: 0.522917
# [16]	valid_0's binary_logloss: 0.518153
# [17]	valid_0's binary_logloss: 0.513336
# [18]	valid_0's binary_logloss: 0.510068
# [19]	valid_0's binary_logloss: 0.505427
# [20]	valid_0's binary_logloss: 0.503345
# [21]	valid_0's binary_logloss: 0.499513
# [22]	valid_0's binary_logloss: 0.496364
# [23]	valid_0's binary_logloss: 0.493622
# [24]	valid_0's binary_logloss: 0.491524
# [25]	valid_0's binary_logloss: 0.489034
# [26]	valid_0's binary_logloss: 0.486064
# [27]	valid_0's binary_logloss: 0.483178
# [28]	valid_0's binary_logloss: 0.481614
# [29]	valid_0's binary_logloss: 0.479941
# [30]	valid_0's binary_logloss: 0.477977
# [31]	valid_0's binary_logloss: 0.476609
# [32]	valid_0's binary_logloss: 0.47426
# [33]	valid_0's binary_logloss: 0.472073
# [34]	valid_0's binary_logloss: 0.47058
# [35]	valid_0's binary_logloss: 0.468767
# [36]	valid_0's binary_logloss: 0.467548
# [37]	valid_0's binary_logloss: 0.465621
# [38]	valid_0's binary_logloss: 0.463896
# [39]	valid_0's binary_logloss: 0.462642
# [40]	valid_0's binary_logloss: 0.460863
# [41]	valid_0's binary_logloss: 0.459775
# [42]	valid_0's binary_logloss: 0.458855
# [43]	valid_0's binary_logloss: 0.457801
# [44]	valid_0's binary_logloss: 0.456613
# [45]	valid_0's binary_logloss: 0.455497
# [46]	valid_0's binary_logloss: 0.454468
# [47]	valid_0's binary_logloss: 0.453315
# [48]	valid_0's binary_logloss: 0.451829
# [49]	valid_0's binary_logloss: 0.450732
# [50]	valid_0's binary_logloss: 0.449254
# [51]	valid_0's binary_logloss: 0.448999
# [52]	valid_0's binary_logloss: 0.448254
# [53]	valid_0's binary_logloss: 0.4475
# [54]	valid_0's binary_logloss: 0.446186
# [55]	valid_0's binary_logloss: 0.445231
# [56]	valid_0's binary_logloss: 0.444497
# [57]	valid_0's binary_logloss: 0.443794
# [58]	valid_0's binary_logloss: 0.442857
# [59]	valid_0's binary_logloss: 0.441192
# [60]	valid_0's binary_logloss: 0.437413
# [61]	valid_0's binary_logloss: 0.435817
# [62]	valid_0's binary_logloss: 0.434754
# [63]	valid_0's binary_logloss: 0.434179
# [64]	valid_0's binary_logloss: 0.433227
# [65]	valid_0's binary_logloss: 0.432255
# [66]	valid_0's binary_logloss: 0.430177
# [67]	valid_0's binary_logloss: 0.429488
# [68]	valid_0's binary_logloss: 0.428794
# [69]	valid_0's binary_logloss: 0.42848
# [70]	valid_0's binary_logloss: 0.426578
# [71]	valid_0's binary_logloss: 0.424799
# [72]	valid_0's binary_logloss: 0.424
# [73]	valid_0's binary_logloss: 0.423287
# [74]	valid_0's binary_logloss: 0.422396
# [75]	valid_0's binary_logloss: 0.421918
# [76]	valid_0's binary_logloss: 0.421009
# [77]	valid_0's binary_logloss: 0.419978
# [78]	valid_0's binary_logloss: 0.419615
# [79]	valid_0's binary_logloss: 0.418202
# [80]	valid_0's binary_logloss: 0.41717
# [81]	valid_0's binary_logloss: 0.416931
# [82]	valid_0's binary_logloss: 0.415683
# [83]	valid_0's binary_logloss: 0.414768
# [84]	valid_0's binary_logloss: 0.41436
# [85]	valid_0's binary_logloss: 0.41358
# [86]	valid_0's binary_logloss: 0.413316
# [87]	valid_0's binary_logloss: 0.412392
# [88]	valid_0's binary_logloss: 0.412128
# [89]	valid_0's binary_logloss: 0.410453
# [90]	valid_0's binary_logloss: 0.409402
# [91]	valid_0's binary_logloss: 0.408157
# [92]	valid_0's binary_logloss: 0.407727
# [93]	valid_0's binary_logloss: 0.406765
# [94]	valid_0's binary_logloss: 0.406159
# [95]	valid_0's binary_logloss: 0.405075
# [96]	valid_0's binary_logloss: 0.404613
# [97]	valid_0's binary_logloss: 0.403835
# [98]	valid_0's binary_logloss: 0.403775
# [99]	valid_0's binary_logloss: 0.402441
# [100]	valid_0's binary_logloss: 0.401805
# LGBMClassifier(max_depth=3)

# %% [markdown]
# # Prediction

# %%
My_pred=Mlgbm.predict(Mx_test)

# %%
Ky_pred=Klgbm.predict(Kx_test)

# %%
Sy_pred=Slgbm.predict(Sx_test)

# %% [markdown]
# # Accuracy

# %%
print("훈련 세트 정확도: {:.3f}".format(Mlgbm.score(Mdf, My)))
print("테스트 세트 정확도: {:.3f}".format(Mlgbm.score(Mx_test, My_test)))
# Out:
# 훈련 세트 정확도: 0.940
# 테스트 세트 정확도: 0.909

# %%
print("훈련 세트 정확도: {:.3f}".format(Klgbm.score(Kdf, Ky)))
print("테스트 세트 정확도: {:.3f}".format(Klgbm.score(Kx_test, Ky_test)))
# Out:
# 훈련 세트 정확도: 0.910
# 테스트 세트 정확도: 0.847

# %%
print("훈련 세트 정확도: {:.3f}".format(Slgbm.score(Sdf, Sy)))
print("테스트 세트 정확도: {:.3f}".format(Slgbm.score(Sx_test, Sy_test)))
# Out:
# 훈련 세트 정확도: 0.879
# 테스트 세트 정확도: 0.826

# %% [markdown]
# # Confusion Matrix

# %%
import sklearn.metrics as mt # 성능지표를 계산하기 위해 import
# 학습결과 평가
print("Train_Accuracy : ", Mlgbm.score(Mdf, My), '\n')
print("Test_Accuracy : ", Mlgbm.score(Mx_test, My_test), '\n')

# 다중 클래스 분류일 경우 average='micro' 를 하이퍼파라미터로 넣어줌(accuracy, matrix 제외)
accuracy = mt.accuracy_score(My_test, My_pred)
recall = mt.recall_score(My_test, My_pred)
precision = mt.precision_score(My_test, My_pred)
f1_score = mt.f1_score(My_test, My_pred)
matrix = mt.confusion_matrix(My_test, My_pred)

print('Accuracy: ', format(accuracy,'.2f'),'\n')
print('Recall: ', format(recall,'.2f'),'\n')
print('Precision: ', format(precision,'.2f'),'\n')
print('F1_score: ', format(f1_score,'.2f'),'\n')
print('Confusion Matrix:','\n', matrix)
# Out:
# Train_Accuracy :  0.9398889600683322
#
# Test_Accuracy :  0.9092649310872895
#
# Accuracy:  0.91
#
# Recall:  0.86
#
# Precision:  0.78
#
# F1_score:  0.82
#
# Confusion Matrix:
#  [[1839  150]
#  [  87  536]]

# %%
import sklearn.metrics as mt # 성능지표를 계산하기 위해 import
# 학습결과 평가
print("Train_Accuracy : ", Klgbm.score(Kdf, Ky), '\n')
print("Test_Accuracy : ", Klgbm.score(Kx_test, Ky_test), '\n')

# 다중 클래스 분류일 경우 average='micro' 를 하이퍼파라미터로 넣어줌(accuracy, matrix 제외)
accuracy = mt.accuracy_score(Ky_test, Ky_pred)
recall = mt.recall_score(Ky_test, Ky_pred)
precision = mt.precision_score(Ky_test, Ky_pred)
f1_score = mt.f1_score(Ky_test, Ky_pred)
matrix = mt.confusion_matrix(Ky_test, Ky_pred)

print('Accuracy: ', format(accuracy,'.2f'),'\n')
print('Recall: ', format(recall,'.2f'),'\n')
print('Precision: ', format(precision,'.2f'),'\n')
print('F1_score: ', format(f1_score,'.2f'),'\n')
print('Confusion Matrix:','\n', matrix)
# Out:
# Train_Accuracy :  0.9097800555199659
#
# Test_Accuracy :  0.8472434915773354
#
# Accuracy:  0.85
#
# Recall:  0.78
#
# Precision:  0.65
#
# F1_score:  0.71
#
# Confusion Matrix:
#  [[1729  260]
#  [ 139  484]]

# %%
import sklearn.metrics as mt # 성능지표를 계산하기 위해 import
# 학습결과 평가
print("Train_Accuracy : ", Slgbm.score(Sdf, Sy), '\n')
print("Test_Accuracy : ", Slgbm.score(Sx_test, Sy_test), '\n')

# 다중 클래스 분류일 경우 average='micro' 를 하이퍼파라미터로 넣어줌(accuracy, matrix 제외)
accuracy = mt.accuracy_score(Sy_test, Sy_pred)
recall = mt.recall_score(Sy_test, Sy_pred)
precision = mt.precision_score(Sy_test, Sy_pred)
f1_score = mt.f1_score(Sy_test, Sy_pred)
matrix = mt.confusion_matrix(Sy_test, Sy_pred)

print('Accuracy: ', format(accuracy,'.2f'),'\n')
print('Recall: ', format(recall,'.2f'),'\n')
print('Precision: ', format(precision,'.2f'),'\n')
print('F1_score: ', format(f1_score,'.2f'),'\n')
print('Confusion Matrix:','\n', matrix)
# Out:
# Train_Accuracy :  0.8790195637508432
#
# Test_Accuracy :  0.8256658595641646
#
# Accuracy:  0.83
#
# Recall:  0.74
#
# Precision:  0.59
#
# F1_score:  0.65
#
# Confusion Matrix:
#  [[1636  290]
#  [ 142  410]]
